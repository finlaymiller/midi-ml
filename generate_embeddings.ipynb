# %% [markdown]
# # generate embeddings
#
# short demo on how to generate midi embeddings from the **Note Encoder** block of the model presented in “Multi-instrument Music Synthesis with Spectrogram Diffusion”.
#
# ![full model architecture](/img/full_model_arch.png)
#
# the model uses the same vocabulary and encoding procedure as MT3 so it uses segments which are 5.12 seconds (20ms spectrogram frames * 256 output positions) long. Each segment produces up to 2048 tokens, which are

# %%
import os
from diffusers.pipelines.deprecated.spectrogram_diffusion.notes_encoder import (
    SpectrogramNotesEncoder,
)
import torch
from diffusers import MidiProcessor

torch.set_grad_enabled(False)
# Out:
# /home/finlay/miniconda/envs/oodenv/lib/python3.9/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)

# %% [markdown]
# ## parameters
#
# load dataset and config and state dictionary for encoder

# %%
cfg = {
    "d_ff": 2048,
    "d_kv": 64,
    "d_model": 768,
    "dropout_rate": 0.1,
    "feed_forward_proj": "gated-gelu_pytorch_tanh",
    "is_decoder": False,
    "max_length": 2048,
    "num_heads": 12,
    "num_layers": 12,
    "vocab_size": 1536,
}
device = "cuda:1"
test_file = "/media/nova/Datasets/sageev-midi/20250110/unsegmented/20240511-088-03/20240511-088-03.mid"

# %% [markdown]
# ## processor and encoder setup

# %%
processor = MidiProcessor()

notes_encoder = SpectrogramNotesEncoder(**cfg).cuda(device=device)
notes_encoder.eval()
sd = torch.load("data/note_encoder.bin", weights_only=True)
notes_encoder.load_state_dict(sd)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### test processor output

# %%
out = processor(test_file)
print(
    f"generated {len(out)} token sets ({torch.tensor(out)[0].shape}) from '{os.path.basename(test_file)}'"
)
torch.tensor(out).shape
# Out:
# generated 71 token sets (torch.Size([2048])) from '20240511-088-03.mid'
# torch.Size([71, 2048])

# %% [markdown]
# ### test encoder output

# %%
for input_tokens in out:
    input_tokens = torch.IntTensor(input_tokens).view(1, -1).cuda(device=device)
    print(f"first 20 tokens:\n\t{input_tokens[:, :20]}")
    tokens_mask = input_tokens > 0
    cutoff = (input_tokens > 0).sum()
    print(tokens_mask.sum().cpu().detach())
    tokens_encoded, tokens_mask = notes_encoder(
        encoder_input_tokens=input_tokens, encoder_inputs_mask=tokens_mask
    )
    print(
        tokens_encoded.shape,
        tokens_encoded[0, cutoff:].sum(),
        (tokens_encoded**2).sum(),
    )
# Out:
# tensor([[1134,   70, 1135, 1133, 1035,   77, 1132, 1035, 1133, 1062, 1066,  107,
#          1054,  137, 1047,  138, 1132, 1054,  169, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(131)
# torch.Size([1, 2048, 768]) tensor(7519.0703, device='cuda:1') tensor(60548.3203, device='cuda:1')
# tensor([[1135, 1052, 1058, 1061, 1134,   35, 1133, 1047,   41, 1132, 1052,   69,
#          1133, 1054,   71, 1132, 1047,   73, 1133, 1062]], device='cuda:1',
#        dtype=torch.int32)
# tensor(143)
# torch.Size([1, 2048, 768]) tensor(1909.0176, device='cuda:1') tensor(50255.8125, device='cuda:1')
# tensor([[1135, 1047, 1134, 1133, 1054,    8, 1132, 1054,   37, 1133, 1061, 1063,
#            39, 1062, 1066,   42, 1132, 1063,   43, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(154)
# torch.Size([1, 2048, 768]) tensor(1365.6938, device='cuda:1') tensor(52895.4688, device='cuda:1')
# tensor([[1135, 1047, 1054, 1058, 1061, 1064, 1134, 1132, 1064,    5, 1054, 1133,
#          1066, 1132, 1061,    6, 1047,    7, 1058,   11]], device='cuda:1',
#        dtype=torch.int32)
# tensor(161)
# torch.Size([1, 2048, 768]) tensor(646.7515, device='cuda:1') tensor(50473.7344, device='cuda:1')
# tensor([[1135, 1047, 1066, 1074, 1078, 1134,    4, 1132, 1066, 1133, 1068,    5,
#          1132, 1074,    7, 1078,    9, 1068,   31, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(170)
# torch.Size([1, 2048, 768]) tensor(-779.1423, device='cuda:1') tensor(51145.1680, device='cuda:1')
# tensor([[1135, 1055, 1061, 1064, 1067, 1071, 1134,   36, 1133, 1047,   63, 1132,
#          1055,   68, 1133, 1054,   69, 1066,   72, 1132]], device='cuda:1',
#        dtype=torch.int32)
# tensor(158)
# torch.Size([1, 2048, 768]) tensor(-3642.1729, device='cuda:1') tensor(45710.2266, device='cuda:1')
# tensor([[1135, 1047, 1134,   34, 1133, 1062,   35, 1059, 1066,   39, 1132, 1059,
#          1066,   41, 1062,   67, 1133, 1054,   72, 1132]], device='cuda:1',
#        dtype=torch.int32)
# tensor(146)
# torch.Size([1, 2048, 768]) tensor(-2195.1328, device='cuda:1') tensor(47649.3594, device='cuda:1')
# tensor([[1135, 1059, 1061, 1062, 1064, 1134,    4, 1132, 1059,    5, 1062,   16,
#          1061,   23, 1064,   29, 1133, 1035,   31, 1067]], device='cuda:1',
#        dtype=torch.int32)
# tensor(157)
# torch.Size([1, 2048, 768]) tensor(3777.5918, device='cuda:1') tensor(54128.1797, device='cuda:1')
# tensor([[1135, 1047, 1074, 1078, 1134,    4, 1132, 1074,    7, 1078,   31, 1133,
#          1054,   34, 1132, 1054,   63, 1133, 1077,   65]], device='cuda:1',
#        dtype=torch.int32)
# tensor(179)
# torch.Size([1, 2048, 768]) tensor(-471.4463, device='cuda:1') tensor(55469.6562, device='cuda:1')
# tensor([[1135, 1054, 1059, 1062, 1066, 1134,   24, 1133, 1047,   29, 1132, 1059,
#            58, 1054, 1133, 1061,   60, 1052,   62, 1064]], device='cuda:1',
#        dtype=torch.int32)
# tensor(144)
# torch.Size([1, 2048, 768]) tensor(7359.4121, device='cuda:1') tensor(59446.4453, device='cuda:1')
# tensor([[1135, 1047, 1134,   24, 1133, 1054,   26, 1062, 1059,   27, 1066,   28,
#          1132, 1054,   31, 1059,   66, 1133, 1059,   68]], device='cuda:1',
#        dtype=torch.int32)
# tensor(137)
# torch.Size([1, 2048, 768]) tensor(-1259.5449, device='cuda:1') tensor(52033.3438, device='cuda:1')
# tensor([[1135, 1061, 1064, 1134,   27, 1133, 1035,   29, 1132, 1061, 1133, 1066,
#            30, 1062,   34, 1132, 1064,   36, 1035,   62]], device='cuda:1',
#        dtype=torch.int32)
# tensor(135)
# torch.Size([1, 2048, 768]) tensor(2770.8750, device='cuda:1') tensor(54902.0078, device='cuda:1')
# tensor([[1135, 1047, 1095, 1134, 1132, 1095,   30, 1133, 1054, 1090,   32, 1050,
#          1059,   35, 1132, 1054, 1059,   37, 1050,   38]], device='cuda:1',
#        dtype=torch.int32)
# tensor(170)
# torch.Size([1, 2048, 768]) tensor(-4411.5161, device='cuda:1') tensor(55008.0938, device='cuda:1')
# tensor([[1135, 1054, 1062, 1066, 1134,   32, 1133, 1050,   38, 1132, 1050,   49,
#          1054,   61, 1133, 1061,   63, 1054, 1064,   64]], device='cuda:1',
#        dtype=torch.int32)
# tensor(150)
# torch.Size([1, 2048, 768]) tensor(501.1637, device='cuda:1') tensor(54589.0078, device='cuda:1')
# tensor([[1135, 1035, 1134,   29, 1133, 1050,   32, 1132, 1050,   62, 1133, 1054,
#            63, 1062,   64, 1061, 1059,   70, 1132, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(147)
# torch.Size([1, 2048, 768]) tensor(2013.3630, device='cuda:1') tensor(50900.4805, device='cuda:1')
# tensor([[1135, 1054, 1059, 1134, 1132, 1059,    9, 1054,   30, 1133, 1035,   64,
#          1054, 1059, 1062,   65, 1066,   70, 1132, 1054]], device='cuda:1',
#        dtype=torch.int32)
# tensor(150)
# torch.Size([1, 2048, 768]) tensor(1189.3159, device='cuda:1') tensor(52329.5781, device='cuda:1')
# tensor([[1135, 1035, 1042, 1055, 1064, 1067, 1134,   18, 1132, 1055,   21, 1067,
#            27, 1133, 1066,   28, 1047, 1054,   29, 1062]], device='cuda:1',
#        dtype=torch.int32)
# tensor(177)
# torch.Size([1, 2048, 768]) tensor(-407.7922, device='cuda:1') tensor(52749.8203, device='cuda:1')
# tensor([[1135, 1035, 1047, 1050, 1059, 1134,   23, 1133, 1041,   38, 1132, 1047,
#            49, 1050,   57, 1133, 1042,   58, 1132, 1059]], device='cuda:1',
#        dtype=torch.int32)
# tensor(139)
# torch.Size([1, 2048, 768]) tensor(3731.1755, device='cuda:1') tensor(52456.7852, device='cuda:1')
# tensor([[1135, 1035, 1042, 1055, 1064, 1134,   22, 1132, 1042,   25, 1064,   26,
#          1133, 1047,   27, 1132, 1055, 1133, 1062,   28]], device='cuda:1',
#        dtype=torch.int32)
# tensor(208)
# torch.Size([1, 2048, 768]) tensor(4702.2300, device='cuda:1') tensor(55935.8828, device='cuda:1')
# tensor([[1135, 1035, 1047, 1062, 1066, 1134,    4, 1132, 1066, 1062,    5, 1047,
#            26, 1133, 1042,   33, 1132, 1042,   61, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(175)
# torch.Size([1, 2048, 768]) tensor(5221.2432, device='cuda:1') tensor(50834.9375, device='cuda:1')
# tensor([[1135, 1035, 1042, 1134,   24, 1133, 1047, 1066, 1062,   30, 1132, 1035,
#            46, 1066,   57, 1047,   58, 1133, 1061, 1035]], device='cuda:1',
#        dtype=torch.int32)
# tensor(176)
# torch.Size([1, 2048, 768]) tensor(3772.6262, device='cuda:1') tensor(54482.2656, device='cuda:1')
# tensor([[1135, 1035, 1134,   29, 1133, 1042,   41, 1132, 1042,   59, 1133, 1047,
#            60, 1059, 1062,   67, 1132, 1047,   71, 1059]], device='cuda:1',
#        dtype=torch.int32)
# tensor(160)
# torch.Size([1, 2048, 768]) tensor(-1325.5928, device='cuda:1') tensor(46546.1953, device='cuda:1')
# tensor([[1135, 1035, 1134,   25, 1133, 1058, 1064, 1067, 1061,   59, 1047,   87,
#          1132, 1047, 1067,   91, 1058,   93, 1133, 1066]], device='cuda:1',
#        dtype=torch.int32)
# tensor(172)
# torch.Size([1, 2048, 768]) tensor(4696.5469, device='cuda:1') tensor(55797.3203, device='cuda:1')
# tensor([[1135, 1042, 1047, 1062, 1066, 1134,   13, 1132, 1062,   15, 1066,   20,
#          1047,   21, 1042,   22, 1133, 1035, 1058, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(190)
# torch.Size([1, 2048, 768]) tensor(6130.7119, device='cuda:1') tensor(54958.0859, device='cuda:1')
# tensor([[1135, 1035, 1042, 1062, 1066, 1134,   21, 1133, 1064,   22, 1132, 1042,
#          1133, 1047, 1061,   24, 1132, 1035,   25, 1066]], device='cuda:1',
#        dtype=torch.int32)
# tensor(181)
# torch.Size([1, 2048, 768]) tensor(1489.8773, device='cuda:1') tensor(56777.5547, device='cuda:1')
# tensor([[1135, 1035, 1047, 1054, 1062, 1134,   18, 1132, 1054, 1062,   20, 1047,
#            23, 1133, 1061, 1042,   54, 1132, 1035,   55]], device='cuda:1',
#        dtype=torch.int32)
# tensor(196)
# torch.Size([1, 2048, 768]) tensor(11428.6689, device='cuda:1') tensor(62989.1445, device='cuda:1')
# tensor([[1135, 1035, 1134,   21, 1133, 1047,   23, 1062,   30, 1132, 1047,   55,
#          1133, 1042,   79, 1132, 1062,   88, 1035, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(140)
# torch.Size([1, 2048, 768]) tensor(15047.1299, device='cuda:1') tensor(55330.1562, device='cuda:1')
# tensor([[1135, 1047, 1071, 1134,   13, 1132, 1047,   15, 1133, 1065,   16, 1066,
#          1132, 1071,   17, 1133, 1035,   20, 1132, 1065]], device='cuda:1',
#        dtype=torch.int32)
# tensor(133)
# torch.Size([1, 2048, 768]) tensor(10954.6758, device='cuda:1') tensor(51429.1562, device='cuda:1')
# tensor([[1135, 1035, 1061, 1134,   21, 1133, 1047, 1062, 1132, 1061,   26, 1035,
#            35, 1062,   52, 1133, 1035,   53, 1132, 1047]], device='cuda:1',
#        dtype=torch.int32)
# tensor(137)
# torch.Size([1, 2048, 768]) tensor(9308.9971, device='cuda:1') tensor(54504.5195, device='cuda:1')
# tensor([[1135, 1035, 1047, 1062, 1134,   14, 1132, 1047,   19, 1062, 1133, 1042,
#            20, 1061,   53, 1047,   55, 1062,   62, 1132]], device='cuda:1',
#        dtype=torch.int32)
# tensor(131)
# torch.Size([1, 2048, 768]) tensor(9551.8545, device='cuda:1') tensor(56189.3945, device='cuda:1')
# tensor([[1135, 1035, 1059, 1134,   18, 1133, 1047,   24, 1132, 1047,   55, 1133,
#          1042,   56, 1054,   57, 1062,   68, 1132, 1042]], device='cuda:1',
#        dtype=torch.int32)
# tensor(91)
# torch.Size([1, 2048, 768]) tensor(3425.2805, device='cuda:1') tensor(48455.1797, device='cuda:1')
# tensor([[1135, 1042, 1054, 1059, 1062, 1134,    5, 1132, 1042,   17, 1133, 1035,
#            29, 1132, 1054,   52, 1133, 1042,   68, 1132]], device='cuda:1',
#        dtype=torch.int32)
# tensor(113)
# torch.Size([1, 2048, 768]) tensor(9140.9414, device='cuda:1') tensor(50189.1523, device='cuda:1')
# tensor([[1135, 1035, 1047, 1062, 1066, 1134,    4, 1132, 1047,    7, 1062,   17,
#          1133, 1042, 1061,   18, 1064,   23, 1132, 1066]], device='cuda:1',
#        dtype=torch.int32)
# tensor(157)
# torch.Size([1, 2048, 768]) tensor(-998.9401, device='cuda:1') tensor(52759.4102, device='cuda:1')
# tensor([[1135, 1047, 1061, 1065, 1134,   17, 1132, 1065, 1133, 1066,   18, 1062,
#            20, 1132, 1061,   22, 1062, 1066,   49, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(174)
# torch.Size([1, 2048, 768]) tensor(-1533.0649, device='cuda:1') tensor(54681.2734, device='cuda:1')
# tensor([[1135, 1054, 1062, 1066, 1134, 1132, 1054,   15, 1133, 1047,   46, 1054,
#            74, 1132, 1054,   82, 1133, 1052, 1061, 1064]], device='cuda:1',
#        dtype=torch.int32)
# tensor(154)
# torch.Size([1, 2048, 768]) tensor(2010.7418, device='cuda:1') tensor(52367.7734, device='cuda:1')
# tensor([[1135, 1047, 1134,   11, 1133, 1059, 1066, 1062,   47, 1050, 1132, 1059,
#            51, 1050,   55, 1062,   79, 1133, 1062, 1059]], device='cuda:1',
#        dtype=torch.int32)
# tensor(136)
# torch.Size([1, 2048, 768]) tensor(5004.6123, device='cuda:1') tensor(54774.8359, device='cuda:1')
# tensor([[1135, 1035, 1042, 1062, 1066, 1134,   10, 1132, 1042,   11, 1133, 1061,
#          1047, 1064,   12, 1054,   13, 1132, 1062, 1035]], device='cuda:1',
#        dtype=torch.int32)
# tensor(172)
# torch.Size([1, 2048, 768]) tensor(-823.5323, device='cuda:1') tensor(53508.6445, device='cuda:1')
# tensor([[1135, 1054, 1059, 1134,   10, 1133, 1062, 1066,   11, 1047, 1132, 1059,
#            12, 1054,   44, 1133, 1054,   48, 1132, 1054]], device='cuda:1',
#        dtype=torch.int32)
# tensor(173)
# torch.Size([1, 2048, 768]) tensor(-1845.3619, device='cuda:1') tensor(54363.3398, device='cuda:1')
# tensor([[1134,   11, 1135, 1133, 1062, 1059, 1066,   14, 1054,   44, 1047,   66,
#          1132, 1054,   74, 1062,   78, 1133, 1052, 1064]], device='cuda:1',
#        dtype=torch.int32)
# tensor(166)
# torch.Size([1, 2048, 768]) tensor(-462.6436, device='cuda:1') tensor(52640.6523, device='cuda:1')
# tensor([[1135, 1062, 1134, 1133, 1035,    7, 1059,    8, 1132, 1062,   12, 1035,
#            41, 1133, 1047,   53, 1061,   58, 1062,   60]], device='cuda:1',
#        dtype=torch.int32)
# tensor(168)
# torch.Size([1, 2048, 768]) tensor(-188.5211, device='cuda:1') tensor(54866.6562, device='cuda:1')
# tensor([[1135, 1047, 1065, 1067, 1071, 1134,   12, 1133, 1054,   16, 1132, 1054,
#            19, 1047,   32, 1071,   36, 1065,   42, 1067]], device='cuda:1',
#        dtype=torch.int32)
# tensor(148)
# torch.Size([1, 2048, 768]) tensor(9066.9814, device='cuda:1') tensor(53459.3047, device='cuda:1')
# tensor([[1135, 1052, 1058, 1061, 1134,   10, 1133, 1047,   24, 1132, 1052,   42,
#          1058,   45, 1133, 1054, 1062,   48, 1132, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(226)
# torch.Size([1, 2048, 768]) tensor(2196.2349, device='cuda:1') tensor(57322.5469, device='cuda:1')
# tensor([[1135, 1059, 1062, 1134,    9, 1133, 1054,   37, 1132, 1059, 1062,   41,
#          1133, 1047,   43, 1061, 1066,   46, 1132, 1054]], device='cuda:1',
#        dtype=torch.int32)
# tensor(153)
# torch.Size([1, 2048, 768]) tensor(-1114.7626, device='cuda:1') tensor(47724.7578, device='cuda:1')
# tensor([[1135, 1059, 1134,    5, 1133, 1035,    7, 1065,    8, 1071,   12, 1132,
#          1035,   18, 1133, 1066,   21, 1132, 1065,   25]], device='cuda:1',
#        dtype=torch.int32)
# tensor(173)
# torch.Size([1, 2048, 768]) tensor(-4423.8145, device='cuda:1') tensor(46339.2500, device='cuda:1')
# tensor([[1135, 1047, 1062, 1066, 1134,    6, 1133, 1052,    8, 1061, 1064,   12,
#          1132, 1062, 1066,   30, 1052,   42, 1061,   44]], device='cuda:1',
#        dtype=torch.int32)
# tensor(150)
# torch.Size([1, 2048, 768]) tensor(6331.7544, device='cuda:1') tensor(53043.0469, device='cuda:1')
# tensor([[1135, 1054, 1059, 1062, 1066, 1134,    6, 1132, 1054,    7, 1133, 1047,
#            16, 1132, 1059,   18, 1062,   43, 1133, 1050]], device='cuda:1',
#        dtype=torch.int32)
# tensor(204)
# torch.Size([1, 2048, 768]) tensor(2875.5298, device='cuda:1') tensor(60593., device='cuda:1')
# tensor([[1134,    4, 1135, 1133, 1062,    5, 1066,    6, 1054,   10, 1132, 1066,
#            11, 1062,   14, 1054,   21, 1133, 1047,   74]], device='cuda:1',
#        dtype=torch.int32)
# tensor(164)
# torch.Size([1, 2048, 768]) tensor(4772.1504, device='cuda:1') tensor(54330.1875, device='cuda:1')
# tensor([[1135, 1035, 1059, 1134,    5, 1132, 1059,    6, 1035,   37, 1133, 1054,
#            38, 1066, 1062,   43, 1132, 1066,   44, 1062]], device='cuda:1',
#        dtype=torch.int32)
# tensor(142)
# torch.Size([1, 2048, 768]) tensor(449.2233, device='cuda:1') tensor(60123.0625, device='cuda:1')
# tensor([[1135, 1042, 1134,    4, 1133, 1054, 1061,    5, 1058,   13, 1132, 1054,
#            19, 1042,   38, 1058, 1061,   39, 1133, 1035]], device='cuda:1',
#        dtype=torch.int32)
# tensor(154)
# torch.Size([1, 2048, 768]) tensor(6501.1875, device='cuda:1') tensor(55640.5469, device='cuda:1')
# tensor([[1135, 1066, 1134,    4, 1133, 1042,    6, 1059,    7, 1062,   16, 1132,
#          1066,   27, 1062,   39, 1133, 1054,   40, 1058]], device='cuda:1',
#        dtype=torch.int32)
# tensor(161)
# torch.Size([1, 2048, 768]) tensor(7323.8008, device='cuda:1') tensor(59364.9219, device='cuda:1')
# tensor([[1135, 1042, 1134,    4, 1133, 1054,    5, 1066,    7, 1062,   10, 1132,
#          1042,   17, 1054,   25, 1062,   31, 1066,   37]], device='cuda:1',
#        dtype=torch.int32)
# tensor(162)
# torch.Size([1, 2048, 768]) tensor(-3718.9365, device='cuda:1') tensor(51602.1250, device='cuda:1')
# tensor([[1135, 1062, 1066, 1134,    4, 1133, 1061,    5, 1042, 1065,    7, 1132,
#          1066,   11, 1062,   40, 1061,   42, 1065, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(165)
# torch.Size([1, 2048, 768]) tensor(-1204.5002, device='cuda:1') tensor(55788.5469, device='cuda:1')
# tensor([[1135, 1042, 1134, 1133, 1054,    4, 1062, 1066,    5, 1132, 1042,   15,
#          1054,   32, 1062,   33, 1066,   37, 1133, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(166)
# torch.Size([1, 2048, 768]) tensor(-87.7764, device='cuda:1') tensor(52352.0898, device='cuda:1')
# tensor([[1135, 1062, 1134, 1133, 1049,    5, 1132, 1062,   37, 1133, 1054,   45,
#          1132, 1054,   51, 1049,   69, 1133, 1062,   70]], device='cuda:1',
#        dtype=torch.int32)
# tensor(197)
# torch.Size([1, 2048, 768]) tensor(-294.1101, device='cuda:1') tensor(53537.3984, device='cuda:1')
# tensor([[1134, 1135, 1133, 1054, 1062, 1071,    9, 1132, 1054,   11, 1071,   14,
#          1062,   74, 1133, 1059, 1062, 1066, 1054,   78]], device='cuda:1',
#        dtype=torch.int32)
# tensor(167)
# torch.Size([1, 2048, 768]) tensor(-3123.7788, device='cuda:1') tensor(54058.5391, device='cuda:1')
# tensor([[1135, 1059, 1061, 1062, 1064, 1066, 1134, 1132, 1066, 1133, 1037,    4,
#          1132, 1064,    5, 1061,    6, 1059,    7, 1062]], device='cuda:1',
#        dtype=torch.int32)
# tensor(174)
# torch.Size([1, 2048, 768]) tensor(4378.9204, device='cuda:1') tensor(57328.0625, device='cuda:1')
# tensor([[1135, 1061, 1064, 1066, 1134,    4, 1132, 1061,    6, 1133, 1056,   11,
#          1132, 1056,   31, 1064,   33, 1133, 1035, 1132]], device='cuda:1',
#        dtype=torch.int32)
# tensor(182)
# torch.Size([1, 2048, 768]) tensor(2159.9900, device='cuda:1') tensor(52670.4805, device='cuda:1')
# tensor([[1135, 1042, 1058, 1061, 1062, 1066, 1134,    9, 1132, 1066,   24, 1042,
#            29, 1058,   31, 1133, 1054,   34, 1132, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(181)
# torch.Size([1, 2048, 768]) tensor(2095.5059, device='cuda:1') tensor(55130.5234, device='cuda:1')
# tensor([[1135, 1042, 1054, 1059, 1062, 1066, 1134, 1132, 1059,    4, 1042,   17,
#          1054,   29, 1066,   30, 1133, 1064,   31, 1058]], device='cuda:1',
#        dtype=torch.int32)
# tensor(170)
# torch.Size([1, 2048, 768]) tensor(-2135.4321, device='cuda:1') tensor(53030.3906, device='cuda:1')
# tensor([[1135, 1042, 1061, 1064, 1134,   23, 1132, 1061,   33, 1133, 1054, 1066,
#            34, 1062,   36, 1132, 1042, 1133, 1061,   38]], device='cuda:1',
#        dtype=torch.int32)
# tensor(170)
# torch.Size([1, 2048, 768]) tensor(-2831.9495, device='cuda:1') tensor(48477.6406, device='cuda:1')
# tensor([[1135, 1054, 1064, 1066, 1134,   11, 1132, 1066,   12, 1064, 1054,   34,
#          1133, 1060, 1062, 1064,   36, 1042,   37, 1063]], device='cuda:1',
#        dtype=torch.int32)
# tensor(186)
# torch.Size([1, 2048, 768]) tensor(1496.3760, device='cuda:1') tensor(54712.4297, device='cuda:1')
# tensor([[1134,   32, 1135, 1133, 1054,   33, 1058, 1064,   42, 1132, 1054,   44,
#          1058,   57, 1064,   66, 1133, 1042,   68, 1058]], device='cuda:1',
#        dtype=torch.int32)
# tensor(177)
# torch.Size([1, 2048, 768]) tensor(-3257.6472, device='cuda:1') tensor(59550.0859, device='cuda:1')
# tensor([[1135, 1054, 1062, 1071, 1134,   18, 1132, 1054,   25, 1062,   28, 1133,
#          1042,   29, 1070,   31, 1059, 1061,   33, 1132]], device='cuda:1',
#        dtype=torch.int32)
# tensor(178)
# torch.Size([1, 2048, 768]) tensor(3128.4128, device='cuda:1') tensor(56011.8516, device='cuda:1')
# tensor([[1135, 1042, 1061, 1065, 1134,   29, 1133, 1054,   30, 1062, 1066,   35,
#          1132, 1061,   37, 1042,   38, 1065,   62, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(176)
# torch.Size([1, 2048, 768]) tensor(2859.5811, device='cuda:1') tensor(56163.2734, device='cuda:1')
# tensor([[1135, 1054, 1062, 1071, 1134,    6, 1132, 1071,   21, 1054,   23, 1062,
#            29, 1133, 1042,   32, 1061, 1070,   64, 1054]], device='cuda:1',
#        dtype=torch.int32)
# tensor(187)
# torch.Size([1, 2048, 768]) tensor(4720.4854, device='cuda:1') tensor(54887.8906, device='cuda:1')
# tensor([[1134,   28, 1135, 1133, 1054, 1071, 1062,   32, 1132, 1054,   62, 1133,
#          1035,   64, 1070,   65, 1061,   67, 1132, 1062]], device='cuda:1',
#        dtype=torch.int32)
# tensor(175)
# torch.Size([1, 2048, 768]) tensor(-32.8394, device='cuda:1') tensor(56489.8359, device='cuda:1')
# tensor([[1134,   26, 1135, 1133, 1035,   31, 1132, 1035,   60, 1133, 1054,   61,
#          1062,   62, 1066,   92, 1132, 1054, 1133, 1042]], device='cuda:1',
#        dtype=torch.int32)
# tensor(170)
# torch.Size([1, 2048, 768]) tensor(-1552.2239, device='cuda:1') tensor(53896.2344, device='cuda:1')
# tensor([[1135, 1042, 1061, 1065, 1134,   29, 1133, 1054,   30, 1062, 1066,   31,
#          1132, 1042,   33, 1065,   34, 1054,   36, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(182)
# torch.Size([1, 2048, 768]) tensor(-341.1145, device='cuda:1') tensor(55931.1328, device='cuda:1')
# tensor([[1134,   25, 1135, 1133, 1042,   27, 1065,   28, 1061,   62, 1132, 1042,
#          1133, 1054,   63, 1062, 1066,   66, 1132, 1061]], device='cuda:1',
#        dtype=torch.int32)
# tensor(169)
# torch.Size([1, 2048, 768]) tensor(1415.8475, device='cuda:1') tensor(53026.8828, device='cuda:1')
# tensor([[1135, 1042, 1134, 1132, 1042,   25, 1133, 1066,   26, 1054,   27, 1062,
#            36, 1132, 1066, 1062,   37, 1054,   59, 1133]], device='cuda:1',
#        dtype=torch.int32)
# tensor(186)
# torch.Size([1, 2048, 768]) tensor(-2754.4463, device='cuda:1') tensor(61968.3281, device='cuda:1')
# tensor([[1134,   63, 1135, 1133, 1054, 1066,   64, 1062, 1059,   69, 1132, 1054,
#          1066,   70, 1059,   72, 1062,   96, 1133, 1059]], device='cuda:1',
#        dtype=torch.int32)
# tensor(27)
# torch.Size([1, 2048, 768]) tensor(4032.1831, device='cuda:1') tensor(52438.0156, device='cuda:1')
